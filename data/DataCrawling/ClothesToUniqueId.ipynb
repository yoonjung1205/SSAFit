# %%
import numpy as np
import pandas as pd
import requests
import csv
import ssl
from urllib.request import urlopen
from urllib.parse import quote_plus

# %%
df = pd.read_csv('C:\\Users\\SSAFY\\Desktop\\ssafy\\DA_pjt\\S06P22E202\\data\\DataCrawling\\musinsa_clothes_skirt.csv')

# %%
print(df.groupby('smallCategory').count())
# Out:
#                clothId  largeCategory  largeCategoryName  smallCategoryName  \
# smallCategory
# 501               1986           1986               1986               1986
# 502               1445           1445               1445               1445
# 503               1123           1123               1123               1123
#
#                colorNo  clothName  brand  image  clothPrice  date  ...  \
# smallCategory                                                      ...
# 501               1986       1986   1986   1986        1986  1986  ...
# 502               1445       1445   1445   1445        1445  1445  ...
# 503               1123       1123   1123   1123        1123  1123  ...
#
#                clothReviewNo   fit  feeling  stretch  visibility  thickness  \
# smallCategory
# 501                     1986  1986     1986     1986        1986       1986
# 502                     1445  1445     1445     1445        1445       1445
# ...

# %% [markdown]
# print(df.shape)

# %%
print(list(df['clothId'].unique()))
# Out:
# [2018790, 1844574, 1672093, 1687533, 1756906, 1311960, 1463374, 1844598, 1819648, 2177198, 2177189, 2381698, 1817336, 2020553, 1812406, 1940355, 1801878, 2324177, 2324242, 2083192, 2297467, 2297145, 2391457, 1509661, 1690590, 1959736, 1844642, 2019175, 2018938, 2140895, 2140994, 2140997, 1432769, 2260050, 2223281, 2356305, 2356019, 1445810, 1218127, 1216618, 1308086, 1284546, 1234110, 1694775, 1629303, 1701250, 1662910, 1921554, 2104001, 2125706, 1862744, 2342709, 2254558, 2227270, 2238389, 2350864, 1359590, 1484015, 1676569, 1216925, 1711112, 1665014, 1362227, 1979032, 1114566, 1406329, 1967978, 1956680, 1817916, 1873765, 2040692, 2071782, 2383587, 2182429, 2403106, 2247071, 2247467, 2405641, 1461559, 1205856, 1262641, 1114559, 1716612, 1202777, 1607458, 2174309, 1956923, 1768375, 1778304, 1588275, 1999671, 1999696, 1792565, 2059595, 2026064, 2039630, 2313535, 2166455, 2389014, 2403682, 2193959, 1075608, 1075582, 2405754, 2409851, 1411149, 1349055, 1235557, 902614, 1095276, 1358878,
# ...

# %%
a = ('a', 'b', 'c', 'd', 'e')
a = list(a)
print(a[0:5])
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
print(482*90)
# Out:
# 43380
